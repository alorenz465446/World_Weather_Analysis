# %%
# pip install citypy

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

from citipy import citipy

import requests

from config import weather_api_key

import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# zip method
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 728

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Make a request

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# print (requests.get(city_url).json())

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": current_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | krasnoselkup
# Processing Record 3 of Set 1 | laguna
# Processing Record 4 of Set 1 | patacamaya
# Processing Record 5 of Set 1 | vestmannaeyjar
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | hayden
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | lampazos de naranjo
# Processing Record 13 of Set 1 | ravar
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | bengkulu
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | polovinnoye
# Processing Record 18 of Set 1 | poum
# Processing Record 19 of Set 1 | koulamoutou
# Processing Record 20 of Set 1 | perbal
# Processing Record 21 of Set 1 | lagoa
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | mengen
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | mirnyy
# Processing Record 28 of Set 1 | koumac
# Processing Record 29 of Set 1 | kumluca
# Processing Record 30 of Set 1 | kropotkin
# Processing Record 31 of Set 1 | vostok
# Processing Record 32 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 1 | aykino
# Processing Record 34 of Set 1 | hasaki
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | sao joao da barra
# Processing Record 37 of Set 1 | denpasar
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | ascension
# Processing Record 42 of Set 1 | tautira
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | concepcion tutuapa
# Processing Record 45 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 46 of Set 1 | port blair
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | samarai
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 1 of Set 2 | ixtapa
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 2 | srednekolymsk
# Processing Record 7 of Set 2 | fort nelson
# Processing Record 8 of Set 2 | iroquois falls
# Processing Record 9 of Set 2 | marienburg
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | baykit
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | onverwacht
# Processing Record 14 of Set 2 | beira
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | mount isa
# Processing Record 17 of Set 2 | sao filipe
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | egvekinot
# Processing Record 20 of Set 2 | flin flon
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | vung tau
# Processing Record 23 of Set 2 | carutapera
# Processing Record 24 of Set 2 | batticaloa
# Processing Record 25 of Set 2 | rikitea
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | souillac
# Processing Record 29 of Set 2 | suntar
# Processing Record 30 of Set 2 | stornoway
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 2 | port-gentil
# Processing Record 34 of Set 2 | manjacaze
# Processing Record 35 of Set 2 | sokolka
# Processing Record 36 of Set 2 | makrikapa
# City not found. Skipping...
# Processing Record 37 of Set 2 | mislinja
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | waingapu
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | manzhouli
# Processing Record 44 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 2 | nyurba
# Processing Record 46 of Set 2 | saldanha
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 2 | luanda
# Processing Record 50 of Set 2 | mmathubudukwane
# Processing Record 1 of Set 3 | batagay
# Processing Record 2 of Set 3 | avera
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | khilok
# Processing Record 5 of Set 3 | alofi
# Processing Record 6 of Set 3 | biltine
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | coquimbo
# Processing Record 10 of Set 3 | fortuna
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | labuhan
# Processing Record 13 of Set 3 | muros
# Processing Record 14 of Set 3 | pevek
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | gat
# Processing Record 19 of Set 3 | leo
# Processing Record 20 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 22 of Set 3 | xiangdong
# City not found. Skipping...
# Processing Record 23 of Set 3 | kovur
# Processing Record 24 of Set 3 | kemi
# Processing Record 25 of Set 3 | isangel
# Processing Record 26 of Set 3 | broken hill
# Processing Record 27 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 3 | sechura
# Processing Record 29 of Set 3 | yulara
# Processing Record 30 of Set 3 | blythe
# Processing Record 31 of Set 3 | bud
# Processing Record 32 of Set 3 | camana
# Processing Record 33 of Set 3 | bose
# Processing Record 34 of Set 3 | vidim
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | cherskiy
# Processing Record 38 of Set 3 | guerrero negro
# Processing Record 39 of Set 3 | la ronge
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | bredasdorp
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | pokrovsk
# Processing Record 44 of Set 3 | fujin
# Processing Record 45 of Set 3 | hermanus
# Processing Record 46 of Set 3 | vila velha
# Processing Record 47 of Set 3 | el alto
# Processing Record 48 of Set 3 | linxia
# Processing Record 49 of Set 3 | mount pleasant
# Processing Record 50 of Set 3 | vila franca do campo
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | virginia beach
# Processing Record 3 of Set 4 | pilar
# Processing Record 4 of Set 4 | sao borja
# Processing Record 5 of Set 4 | oranjemund
# Processing Record 6 of Set 4 | pacific grove
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | mosquera
# Processing Record 10 of Set 4 | burnie
# Processing Record 11 of Set 4 | namtsy
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | jumla
# Processing Record 14 of Set 4 | los llanos de aridane
# Processing Record 15 of Set 4 | altay
# Processing Record 16 of Set 4 | soledade
# Processing Record 17 of Set 4 | grajau
# Processing Record 18 of Set 4 | manicore
# Processing Record 19 of Set 4 | moose factory
# Processing Record 20 of Set 4 | te anau
# Processing Record 21 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 4 | cabo san lucas
# Processing Record 23 of Set 4 | arlit
# Processing Record 24 of Set 4 | provideniya
# Processing Record 25 of Set 4 | aswan
# Processing Record 26 of Set 4 | slonim
# Processing Record 27 of Set 4 | ouesso
# Processing Record 28 of Set 4 | mahajanga
# Processing Record 29 of Set 4 | saint-augustin
# Processing Record 30 of Set 4 | kruisfontein
# Processing Record 31 of Set 4 | mpongwe
# Processing Record 32 of Set 4 | bluff
# Processing Record 33 of Set 4 | isla mujeres
# Processing Record 34 of Set 4 | ossora
# Processing Record 35 of Set 4 | paris
# Processing Record 36 of Set 4 | chokurdakh
# Processing Record 37 of Set 4 | san joaquin
# Processing Record 38 of Set 4 | bilma
# Processing Record 39 of Set 4 | ajdabiya
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | yaan
# Processing Record 42 of Set 4 | inhambane
# Processing Record 43 of Set 4 | solnechnyy
# Processing Record 44 of Set 4 | mount gambier
# Processing Record 45 of Set 4 | raudeberg
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | tahta
# Processing Record 48 of Set 4 | husavik
# Processing Record 49 of Set 4 | nikolskoye
# Processing Record 50 of Set 4 | osmanabad
# Processing Record 1 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 2 of Set 5 | barrow
# Processing Record 3 of Set 5 | dhidhdhoo
# Processing Record 4 of Set 5 | aksay
# Processing Record 5 of Set 5 | tual
# Processing Record 6 of Set 5 | zhangjiakou
# Processing Record 7 of Set 5 | hibbing
# Processing Record 8 of Set 5 | nenjiang
# Processing Record 9 of Set 5 | maumere
# Processing Record 10 of Set 5 | khairpur
# Processing Record 11 of Set 5 | nalut
# Processing Record 12 of Set 5 | pisco
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | constitucion
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | la sarre
# Processing Record 17 of Set 5 | asau
# Processing Record 18 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 5 | hami
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | kemijarvi
# Processing Record 24 of Set 5 | codrington
# Processing Record 25 of Set 5 | beringovskiy
# Processing Record 26 of Set 5 | makakilo city
# Processing Record 27 of Set 5 | sao miguel do araguaia
# Processing Record 28 of Set 5 | koslan
# Processing Record 29 of Set 5 | waipawa
# Processing Record 30 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 5 | havelock
# Processing Record 32 of Set 5 | mogadishu
# Processing Record 33 of Set 5 | kudahuvadhoo
# Processing Record 34 of Set 5 | bembereke
# Processing Record 35 of Set 5 | esperance
# Processing Record 36 of Set 5 | esil
# Processing Record 37 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 5 | jining
# Processing Record 39 of Set 5 | conde
# Processing Record 40 of Set 5 | nemuro
# Processing Record 41 of Set 5 | coihaique
# Processing Record 42 of Set 5 | dali
# Processing Record 43 of Set 5 | luoyang
# Processing Record 44 of Set 5 | okhotsk
# Processing Record 45 of Set 5 | nova olinda do norte
# Processing Record 46 of Set 5 | talcahuano
# Processing Record 47 of Set 5 | singaraja
# Processing Record 48 of Set 5 | custoias
# Processing Record 49 of Set 5 | komsomolskiy
# Processing Record 50 of Set 5 | mapiripan
# Processing Record 1 of Set 6 | medak
# Processing Record 2 of Set 6 | wiarton
# Processing Record 3 of Set 6 | boa vista
# Processing Record 4 of Set 6 | tshikapa
# Processing Record 5 of Set 6 | champerico
# Processing Record 6 of Set 6 | colac
# Processing Record 7 of Set 6 | tuatapere
# Processing Record 8 of Set 6 | nouadhibou
# Processing Record 9 of Set 6 | port hardy
# Processing Record 10 of Set 6 | carmen
# Processing Record 11 of Set 6 | wattegama
# Processing Record 12 of Set 6 | hit
# Processing Record 13 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 6 | bajil
# Processing Record 15 of Set 6 | kavieng
# Processing Record 16 of Set 6 | madaoua
# Processing Record 17 of Set 6 | kolosovka
# Processing Record 18 of Set 6 | micheweni
# Processing Record 19 of Set 6 | ahipara
# Processing Record 20 of Set 6 | srandakan
# Processing Record 21 of Set 6 | xiaoweizhai
# Processing Record 22 of Set 6 | walvis bay
# Processing Record 23 of Set 6 | umm lajj
# Processing Record 24 of Set 6 | eenhana
# Processing Record 25 of Set 6 | talnakh
# Processing Record 26 of Set 6 | kainantu
# Processing Record 27 of Set 6 | dikson
# Processing Record 28 of Set 6 | torbay
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | esmeraldas
# Processing Record 31 of Set 6 | buarcos
# Processing Record 32 of Set 6 | nioro
# Processing Record 33 of Set 6 | inongo
# Processing Record 34 of Set 6 | fort frances
# Processing Record 35 of Set 6 | kyzyl-suu
# Processing Record 36 of Set 6 | villa carlos paz
# Processing Record 37 of Set 6 | saint-joseph
# Processing Record 38 of Set 6 | port hedland
# Processing Record 39 of Set 6 | vao
# Processing Record 40 of Set 6 | krasnyy chikoy
# Processing Record 41 of Set 6 | la asuncion
# Processing Record 42 of Set 6 | birao
# Processing Record 43 of Set 6 | tessalit
# Processing Record 44 of Set 6 | batagay-alyta
# Processing Record 45 of Set 6 | meulaboh
# Processing Record 46 of Set 6 | harper
# Processing Record 47 of Set 6 | vardo
# Processing Record 48 of Set 6 | soanierana ivongo
# Processing Record 49 of Set 6 | yate
# Processing Record 50 of Set 6 | henties bay
# Processing Record 1 of Set 7 | nantucket
# Processing Record 2 of Set 7 | severo-kurilsk
# Processing Record 3 of Set 7 | wanaka
# Processing Record 4 of Set 7 | daytona beach
# Processing Record 5 of Set 7 | ranfurly
# Processing Record 6 of Set 7 | kyaukse
# Processing Record 7 of Set 7 | oussouye
# Processing Record 8 of Set 7 | igrim
# Processing Record 9 of Set 7 | wagar
# Processing Record 10 of Set 7 | puerto cortes
# City not found. Skipping...
# Processing Record 11 of Set 7 | pervomayskoye
# Processing Record 12 of Set 7 | lewistown
# Processing Record 13 of Set 7 | arua
# Processing Record 14 of Set 7 | biak
# Processing Record 15 of Set 7 | arrifes
# Processing Record 16 of Set 7 | honiara
# Processing Record 17 of Set 7 | dunedin
# Processing Record 18 of Set 7 | zhoucheng
# Processing Record 19 of Set 7 | winton
# Processing Record 20 of Set 7 | iqaluit
# Processing Record 21 of Set 7 | san patricio
# Processing Record 22 of Set 7 | manta
# Processing Record 23 of Set 7 | mar del plata
# Processing Record 24 of Set 7 | santarem
# Processing Record 25 of Set 7 | xingyi
# Processing Record 26 of Set 7 | yankton
# Processing Record 27 of Set 7 | itambacuri
# Processing Record 28 of Set 7 | joshimath
# Processing Record 29 of Set 7 | rocha
# Processing Record 30 of Set 7 | tamandare
# Processing Record 31 of Set 7 | durres
# Processing Record 32 of Set 7 | amambai
# Processing Record 33 of Set 7 | wanning
# Processing Record 34 of Set 7 | dubrovka
# Processing Record 35 of Set 7 | agua branca
# Processing Record 36 of Set 7 | norman wells
# Processing Record 37 of Set 7 | ramnagar
# Processing Record 38 of Set 7 | kieta
# Processing Record 39 of Set 7 | mugumu
# Processing Record 40 of Set 7 | ponta do sol
# Processing Record 41 of Set 7 | akdepe
# Processing Record 42 of Set 7 | san fernando
# Processing Record 43 of Set 7 | hovd
# Processing Record 44 of Set 7 | tateyama
# Processing Record 45 of Set 7 | mayya
# Processing Record 46 of Set 7 | orthez
# Processing Record 47 of Set 7 | pochutla
# Processing Record 48 of Set 7 | taraz
# Processing Record 49 of Set 7 | chivay
# Processing Record 50 of Set 7 | ukiah
# Processing Record 1 of Set 8 | marawi
# Processing Record 2 of Set 8 | bara
# Processing Record 3 of Set 8 | sete
# Processing Record 4 of Set 8 | yanam
# Processing Record 5 of Set 8 | broome
# Processing Record 6 of Set 8 | padang
# Processing Record 7 of Set 8 | khorramshahr
# Processing Record 8 of Set 8 | affery
# Processing Record 9 of Set 8 | klaksvik
# Processing Record 10 of Set 8 | taunggyi
# Processing Record 11 of Set 8 | bobcaygeon
# Processing Record 12 of Set 8 | merauke
# Processing Record 13 of Set 8 | seminole
# Processing Record 14 of Set 8 | balkanabat
# Processing Record 15 of Set 8 | haukipudas
# Processing Record 16 of Set 8 | sept-iles
# Processing Record 17 of Set 8 | omboue
# Processing Record 18 of Set 8 | plast
# Processing Record 19 of Set 8 | sitka
# Processing Record 20 of Set 8 | birin
# Processing Record 21 of Set 8 | adrar
# Processing Record 22 of Set 8 | katangli
# Processing Record 23 of Set 8 | bonthe
# Processing Record 24 of Set 8 | kirakira
# Processing Record 25 of Set 8 | marsa matruh
# Processing Record 26 of Set 8 | ribeira brava
# Processing Record 27 of Set 8 | pacifica
# Processing Record 28 of Set 8 | katsuura
# Processing Record 29 of Set 8 | abonnema
# Processing Record 30 of Set 8 | deputatskiy
# Processing Record 31 of Set 8 | malanje
# Processing Record 32 of Set 8 | skelleftea
# Processing Record 33 of Set 8 | barcelos
# Processing Record 34 of Set 8 | misratah
# Processing Record 35 of Set 8 | port hueneme
# Processing Record 36 of Set 8 | caravelas
# Processing Record 37 of Set 8 | vrbas
# Processing Record 38 of Set 8 | peace river
# Processing Record 39 of Set 8 | sao gabriel da cachoeira
# Processing Record 40 of Set 8 | dwarka
# Processing Record 41 of Set 8 | smolenka
# Processing Record 42 of Set 8 | yar-sale
# Processing Record 43 of Set 8 | nome
# Processing Record 44 of Set 8 | tripoli
# Processing Record 45 of Set 8 | haines junction
# Processing Record 46 of Set 8 | nanortalik
# Processing Record 47 of Set 8 | genhe
# Processing Record 48 of Set 8 | daura
# Processing Record 49 of Set 8 | bjala
# City not found. Skipping...
# Processing Record 50 of Set 8 | namatanai
# Processing Record 1 of Set 9 | banikoara
# Processing Record 2 of Set 9 | kushiro
# Processing Record 3 of Set 9 | shimoni
# Processing Record 4 of Set 9 | turukhansk
# Processing Record 5 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 9 | formosa do rio preto
# Processing Record 7 of Set 9 | la romana
# Processing Record 8 of Set 9 | beloha
# Processing Record 9 of Set 9 | progreso
# Processing Record 10 of Set 9 | odweyne
# Processing Record 11 of Set 9 | san cristobal
# Processing Record 12 of Set 9 | rudnaya pristan
# Processing Record 13 of Set 9 | grindavik
# Processing Record 14 of Set 9 | faanui
# Processing Record 15 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 9 | port lincoln
# Processing Record 17 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 9 | gilbues
# Processing Record 19 of Set 9 | edd
# Processing Record 20 of Set 9 | hirara
# Processing Record 21 of Set 9 | qui nhon
# Processing Record 22 of Set 9 | tonantins
# Processing Record 23 of Set 9 | cidreira
# Processing Record 24 of Set 9 | leshukonskoye
# Processing Record 25 of Set 9 | raub
# Processing Record 26 of Set 9 | silver city
# Processing Record 27 of Set 9 | sorland
# Processing Record 28 of Set 9 | naryan-mar
# Processing Record 29 of Set 9 | penzance
# Processing Record 30 of Set 9 | moerai
# Processing Record 31 of Set 9 | lac du bonnet
# Processing Record 32 of Set 9 | acarau
# Processing Record 33 of Set 9 | sitrah
# Processing Record 34 of Set 9 | puerto ayacucho
# Processing Record 35 of Set 9 | sioux lookout
# Processing Record 36 of Set 9 | moron
# Processing Record 37 of Set 9 | suncuius
# Processing Record 38 of Set 9 | terrace bay
# Processing Record 39 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 40 of Set 9 | diamantino
# Processing Record 41 of Set 9 | along
# Processing Record 42 of Set 9 | hanna
# Processing Record 43 of Set 9 | basco
# Processing Record 44 of Set 9 | yumen
# Processing Record 45 of Set 9 | amarante do maranhao
# Processing Record 46 of Set 9 | honningsvag
# Processing Record 47 of Set 9 | sibut
# Processing Record 48 of Set 9 | east wenatchee bench
# Processing Record 49 of Set 9 | gilleleje
# Processing Record 50 of Set 9 | tokmak
# Processing Record 1 of Set 10 | san quintin
# Processing Record 2 of Set 10 | korgen
# Processing Record 3 of Set 10 | peniche
# Processing Record 4 of Set 10 | georgetown
# Processing Record 5 of Set 10 | general roca
# Processing Record 6 of Set 10 | yemtsa
# Processing Record 7 of Set 10 | umm kaddadah
# Processing Record 8 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 10 | eureka
# Processing Record 10 of Set 10 | bethel
# Processing Record 11 of Set 10 | opuwo
# Processing Record 12 of Set 10 | palmer
# Processing Record 13 of Set 10 | vilhena
# Processing Record 14 of Set 10 | chumikan
# Processing Record 15 of Set 10 | yenagoa
# Processing Record 16 of Set 10 | veraval
# Processing Record 17 of Set 10 | kosh-agach
# Processing Record 18 of Set 10 | tiksi
# Processing Record 19 of Set 10 | sinnamary
# Processing Record 20 of Set 10 | weihe
# Processing Record 21 of Set 10 | giddalur
# Processing Record 22 of Set 10 | mulchen
# Processing Record 23 of Set 10 | longhua
# Processing Record 24 of Set 10 | aranda de duero
# Processing Record 25 of Set 10 | sambava
# Processing Record 26 of Set 10 | camiri
# Processing Record 27 of Set 10 | udachnyy
# Processing Record 28 of Set 10 | kalashnikovo
# Processing Record 29 of Set 10 | ponta delgada
# Processing Record 30 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 10 | camacha
# Processing Record 32 of Set 10 | pau
# Processing Record 33 of Set 10 | margate
# Processing Record 34 of Set 10 | matara
# Processing Record 35 of Set 10 | ampanihy
# Processing Record 36 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 10 | oksfjord
# Processing Record 38 of Set 10 | cayenne
# Processing Record 39 of Set 10 | zhigansk
# Processing Record 40 of Set 10 | santa lucia
# Processing Record 41 of Set 10 | taoudenni
# Processing Record 42 of Set 10 | severo-yeniseyskiy
# Processing Record 43 of Set 10 | luderitz
# Processing Record 44 of Set 10 | martapura
# Processing Record 45 of Set 10 | nador
# Processing Record 46 of Set 10 | marrakesh
# Processing Record 47 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 10 | polikhronon
# Processing Record 49 of Set 10 | hearst
# Processing Record 50 of Set 10 | porto novo
# Processing Record 1 of Set 11 | west wendover
# Processing Record 2 of Set 11 | filadelfia
# Processing Record 3 of Set 11 | half moon bay
# Processing Record 4 of Set 11 | almaty
# Processing Record 5 of Set 11 | fort wellington
# Processing Record 6 of Set 11 | coos bay
# Processing Record 7 of Set 11 | buta
# Processing Record 8 of Set 11 | atasu
# Processing Record 9 of Set 11 | nelson bay
# Processing Record 10 of Set 11 | chapais
# Processing Record 11 of Set 11 | guaratuba
# Processing Record 12 of Set 11 | bathsheba
# Processing Record 13 of Set 11 | mbaiki
# Processing Record 14 of Set 11 | kokkola
# Processing Record 15 of Set 11 | vagur
# Processing Record 16 of Set 11 | geraldton
# Processing Record 17 of Set 11 | santa vitoria do palmar
# Processing Record 18 of Set 11 | pitimbu
# Processing Record 19 of Set 11 | mehamn
# Processing Record 20 of Set 11 | chicama
# Processing Record 21 of Set 11 | el carmen
# Processing Record 22 of Set 11 | imeni poliny osipenko
# Processing Record 23 of Set 11 | saint-ambroise
# Processing Record 24 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 11 | kosai
# Processing Record 26 of Set 11 | hofn
# Processing Record 27 of Set 11 | quatre cocos
# Processing Record 28 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 11 | lata
# Processing Record 30 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 11 | norsup
# Processing Record 32 of Set 11 | rehoboth
# Processing Record 33 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 11 | salalah
# Processing Record 35 of Set 11 | leningradskiy
# Processing Record 36 of Set 11 | kiunga
# Processing Record 37 of Set 11 | san felipe
# Processing Record 38 of Set 11 | knevichi
# Processing Record 39 of Set 11 | nuristan
# Processing Record 40 of Set 11 | emba
# Processing Record 41 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 11 | nago
# Processing Record 43 of Set 11 | itaituba
# Processing Record 44 of Set 11 | lokossa
# Processing Record 45 of Set 11 | leninskoye
# Processing Record 46 of Set 11 | cedar city
# Processing Record 47 of Set 11 | askiz
# Processing Record 48 of Set 11 | duz
# City not found. Skipping...
# Processing Record 49 of Set 11 | uchaly
# Processing Record 50 of Set 11 | hengshui
# Processing Record 1 of Set 12 | neiafu
# Processing Record 2 of Set 12 | gobabis
# Processing Record 3 of Set 12 | anadyr
# Processing Record 4 of Set 12 | lethem
# Processing Record 5 of Set 12 | lloydminster
# Processing Record 6 of Set 12 | manzanillo
# Processing Record 7 of Set 12 | ippy
# Processing Record 8 of Set 12 | svobodnyy
# Processing Record 9 of Set 12 | guanare
# Processing Record 10 of Set 12 | ulladulla
# Processing Record 11 of Set 12 | mayo
# Processing Record 12 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 13 of Set 12 | bria
# Processing Record 14 of Set 12 | kalmunai
# Processing Record 15 of Set 12 | sroda wielkopolska
# Processing Record 16 of Set 12 | hobyo
# Processing Record 17 of Set 12 | pa sang
# Processing Record 18 of Set 12 | tiznit
# Processing Record 19 of Set 12 | zaysan
# Processing Record 20 of Set 12 | bandarbeyla
# Processing Record 21 of Set 12 | mpraeso
# Processing Record 22 of Set 12 | ola
# Processing Record 23 of Set 12 | kyra
# Processing Record 24 of Set 12 | sao felix do xingu
# Processing Record 25 of Set 12 | flinders
# Processing Record 26 of Set 12 | frederikshavn
# Processing Record 27 of Set 12 | nangong
# Processing Record 28 of Set 12 | dumai
# Processing Record 29 of Set 12 | erenhot
# Processing Record 30 of Set 12 | ardesen
# Processing Record 31 of Set 12 | bonavista
# Processing Record 32 of Set 12 | barkhan
# Processing Record 33 of Set 12 | korhogo
# Processing Record 34 of Set 12 | lugo
# Processing Record 35 of Set 12 | port keats
# Processing Record 36 of Set 12 | palaikastron
# Processing Record 37 of Set 12 | riyadh
# Processing Record 38 of Set 12 | byron bay
# Processing Record 39 of Set 12 | najran
# Processing Record 40 of Set 12 | kailua
# Processing Record 41 of Set 12 | uspenka
# Processing Record 42 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 12 | goderich
# Processing Record 44 of Set 12 | wanlaweyn
# Processing Record 45 of Set 12 | muroto
# Processing Record 46 of Set 12 | quelimane
# Processing Record 47 of Set 12 | aksu
# Processing Record 48 of Set 12 | somerset
# Processing Record 49 of Set 12 | kangar
# Processing Record 50 of Set 12 | rebrikha
# Processing Record 1 of Set 13 | chulman
# Processing Record 2 of Set 13 | aybak
# City not found. Skipping...
# Processing Record 3 of Set 13 | sur
# Processing Record 4 of Set 13 | qaqortoq
# Processing Record 5 of Set 13 | kinshasa
# Processing Record 6 of Set 13 | luganville
# Processing Record 7 of Set 13 | manakara
# Processing Record 8 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 13 | takoradi
# Processing Record 10 of Set 13 | pascagoula
# Processing Record 11 of Set 13 | syracuse
# Processing Record 12 of Set 13 | dzaoudzi
# Processing Record 13 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 14 of Set 13 | oran
# Processing Record 15 of Set 13 | reinbek
# Processing Record 16 of Set 13 | bairiki
# Processing Record 17 of Set 13 | sibolga
# Processing Record 18 of Set 13 | bossembele
# City not found. Skipping...
# Processing Record 19 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 20 of Set 13 | kouango
# Processing Record 21 of Set 13 | paamiut
# Processing Record 22 of Set 13 | amapa
# Processing Record 23 of Set 13 | staroye drozhzhanoye
# Processing Record 24 of Set 13 | ambovombe
# Processing Record 25 of Set 13 | lano
# Processing Record 26 of Set 13 | teya
# Processing Record 27 of Set 13 | sumbe
# Processing Record 28 of Set 13 | zhuanghe
# Processing Record 29 of Set 13 | ostrovnoy
# Processing Record 30 of Set 13 | winnemucca
# Processing Record 31 of Set 13 | mangai
# Processing Record 32 of Set 13 | lubao
# Processing Record 33 of Set 13 | diego de almagro
# Processing Record 34 of Set 13 | kabare
# Processing Record 35 of Set 13 | cuenca
# Processing Record 36 of Set 13 | thunder bay
# Processing Record 37 of Set 13 | whyalla
# Processing Record 38 of Set 13 | kloulklubed
# Processing Record 39 of Set 13 | lazaro cardenas
# Processing Record 40 of Set 13 | conceicao do coite
# Processing Record 41 of Set 13 | sao joao da ponte
# Processing Record 42 of Set 13 | gouyave
# Processing Record 43 of Set 13 | port augusta
# Processing Record 44 of Set 13 | puerto baquerizo moreno
# Processing Record 45 of Set 13 | carora
# Processing Record 46 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 13 | nandi hills
# Processing Record 48 of Set 13 | alice springs
# Processing Record 49 of Set 13 | knysna
# Processing Record 50 of Set 13 | tura
# Processing Record 1 of Set 14 | guelengdeng
# City not found. Skipping...
# Processing Record 2 of Set 14 | jabinyanah
# Processing Record 3 of Set 14 | eyl
# Processing Record 4 of Set 14 | asfi
# Processing Record 5 of Set 14 | huilong
# Processing Record 6 of Set 14 | bocana de paiwas
# Processing Record 7 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 14 | voh
# Processing Record 9 of Set 14 | pousat
# City not found. Skipping...
# Processing Record 10 of Set 14 | hambantota
# Processing Record 11 of Set 14 | pakdasht
# Processing Record 12 of Set 14 | iquitos
# Processing Record 13 of Set 14 | lima
# Processing Record 14 of Set 14 | yabrud
# Processing Record 15 of Set 14 | puri
# Processing Record 16 of Set 14 | yabelo
# Processing Record 17 of Set 14 | tanete
# Processing Record 18 of Set 14 | carbonia
# Processing Record 19 of Set 14 | celestun
# Processing Record 20 of Set 14 | ust-ilimsk
# Processing Record 21 of Set 14 | jinan
# Processing Record 22 of Set 14 | vanavara
# Processing Record 23 of Set 14 | monte santo de minas
# Processing Record 24 of Set 14 | owase
# Processing Record 25 of Set 14 | astara
# Processing Record 26 of Set 14 | nsunga
# Processing Record 27 of Set 14 | berdigestyakh
# Processing Record 28 of Set 14 | cockburn town
# Processing Record 29 of Set 14 | saint anthony
# Processing Record 30 of Set 14 | nicoya
# Processing Record 31 of Set 14 | rawson
# Processing Record 32 of Set 14 | arbagar
# Processing Record 33 of Set 14 | morro bay
# Processing Record 34 of Set 14 | gilgit
# Processing Record 35 of Set 14 | almaznyy
# Processing Record 36 of Set 14 | monrovia
# Processing Record 37 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 38 of Set 14 | monteagudo
# Processing Record 39 of Set 14 | menongue
# Processing Record 40 of Set 14 | itigi
# Processing Record 41 of Set 14 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 42 of Set 14 | kaeo
# Processing Record 43 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 44 of Set 14 | kennett
# Processing Record 45 of Set 14 | solikamsk
# Processing Record 46 of Set 14 | naze
# Processing Record 47 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 48 of Set 14 | cubuk
# Processing Record 49 of Set 14 | salinopolis
# Processing Record 50 of Set 14 | amurzet
# Processing Record 1 of Set 15 | el sauzal
# Processing Record 2 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 3 of Set 15 | markova
# Processing Record 4 of Set 15 | college
# Processing Record 5 of Set 15 | amalapuram
# Processing Record 6 of Set 15 | pafos
# Processing Record 7 of Set 15 | astoria
# Processing Record 8 of Set 15 | fairbanks
# Processing Record 9 of Set 15 | hay river
# Processing Record 10 of Set 15 | irbeyskoye
# Processing Record 11 of Set 15 | moundou
# Processing Record 12 of Set 15 | jaguaruna
# Processing Record 13 of Set 15 | tommot
# Processing Record 14 of Set 15 | marzuq
# Processing Record 15 of Set 15 | ketchikan
# Processing Record 16 of Set 15 | maku
# Processing Record 17 of Set 15 | kualakapuas
# Processing Record 18 of Set 15 | ngerengere
# Processing Record 19 of Set 15 | manokwari
# Processing Record 20 of Set 15 | billings
# Processing Record 21 of Set 15 | macherla
# Processing Record 22 of Set 15 | madimba
# Processing Record 23 of Set 15 | kahului
# Processing Record 24 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 15 | pudozh
# Processing Record 27 of Set 15 | koygorodok
# Processing Record 28 of Set 15 | maragogi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# New order
new_column_order = ['City', 'Country', 'Date', 'Current Description', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                   City Country                 Date Current Description  \
# 0               Albany      US  2022-08-11 22:16:11       broken clouds
# 1         Krasnoselkup      RU  2022-08-11 22:26:52     overcast clouds
# 2               Laguna      US  2022-08-11 22:20:09           clear sky
# 3           Patacamaya      BO  2022-08-11 22:26:52           clear sky
# 4       Vestmannaeyjar      IS  2022-08-11 22:26:52     overcast clouds
# 5               Hayden      US  2022-08-11 22:26:45                haze
# 6              Ushuaia      AR  2022-08-11 22:26:53    scattered clouds
# 7         Punta Arenas      CL  2022-08-11 22:17:25       broken clouds
# 8            Saskylakh      RU  2022-08-11 22:20:15     overcast clouds
# 9  Lampazos De Naranjo      MX  2022-08-11 22:26:53    scattered clouds
#
#        Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0  42.6001  -73.9662     81.68        53          83        1.01
# 1  65.7000   82.4667     47.82        73          98        4.45
# 2  38.4210 -121.4238     96.35        27           0        8.05
# 3 -17.2333  -67.9167     55.00        24           0        4.99
# 4  63.4427  -20.2734     51.46        94         100       13.67
# 5  47.7660 -116.7866     96.21        34           0        1.99
# 6 -54.8000  -68.3000     35.26        87          40        0.00
# 7 -53.1500  -70.9167     35.71        69          75       10.36
# 8  71.9167  114.0833     43.66        69         100        7.09
# 9  27.0167 -100.5167    100.31        26          46       15.26

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
